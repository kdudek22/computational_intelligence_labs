# %% [markdown]
# $\Huge Computational$ $\Huge Intelligence$ $\Huge Lab$
#
# $\Huge  Assignment$ $\Huge 1$
# ---
# Fill in your name, surname and group...
# ---

# %% [markdown]
# # 1.1 Function
# Consider the following Python class.

# %%
import numpy as np

class Function:
  def __init__(self,n_h,activation=lambda x : x):
    self.f=activation
    self.W0=np.random.randn(n_h,1)*np.sqrt(1/n_h)
    self.b0=np.zeros((n_h,1))
    self.W1=np.random.randn(1,n_h)*np.sqrt(1/n_h)
    self.b1=np.zeros((1,1))

  def __call__(self,x):
    z=self.W0*x+self.b0
    a  = self.f(z)
    y=np.dot(self.W1,a)+self.b1
    return y[0]

x=np.linspace(0,10,100)
f=Function(4)
y=f(x)

# %% [markdown]
# Operations placed in the function call operator can be expressed as:
#
#
# *   $z = W_0\cdot x+b_0$
# *   $a = f(z)$
# *   $y = W_1*a+b_1$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TODO 1.1.1** Create function objects for various values of ```n_h``` and display their shapes. Use a for loop

# %%
import matplotlib.pyplot as plt

for i in range(1,10):
    plt.plot(x, Function(i)(x))

# %% [markdown]
# Run the following code.
#
# **Question: What are the shapes of function graphs? Why there are multiple plots?**

# %%
import matplotlib.pyplot as plt
for i in range(10):
  plt.plot(x,Function(5)(x))

# %% [markdown]
# **TODO 1.1.2** Define two functions:
#
# *   $sigmoid(x)=\frac{1}{1+exp(-x)}$
# *   $rbf(x)=exp(-x^2)$

# %%
def sigmoid(z):
  return 1/(1 + np.exp(-z))

def rbf(z):
  return np.exp(-1*np.square(z))

# %% [markdown]
# then plot their graphs

# %%
import matplotlib.pyplot as plt
x=np.linspace(-10,10,100)

plt.plot(x,sigmoid(x),c='r',label='sigmoid')
plt.plot(x,rbf(x),c='b',label='rbf')
plt.legend()

# %% [markdown]
# **TODO 1.1.3** Display several function plots for activation = sigmoid

# %%
for i in range(10):
    plt.plot(x, Function(5, activation=sigmoid)(x))

# %% [markdown]
# **TODO 1.1.4** Display several function plots for activation = rbf

# %%
for i in range(10):
    plt.plot(x, Function(5, activation=rbf)(x))

# %% [markdown]
# # 1.2 Implementation based on TensorFlow

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0

# %%
import tensorflow as tf


class Function:
  def __init__(self,n_h,activation = lambda x:x):
    self.f = activation
    self.W0=tf.Variable(np.random.randn(n_h,1)*np.sqrt(1/n_h))
    self.b0=tf.Variable(np.zeros((n_h,1)))
    self.W1=tf.Variable(np.random.randn(1,n_h)*np.sqrt(1/n_h))
    self.b1=tf.Variable(np.zeros((1,1)))


  def __call__(self,x):
    z=self.W0*x+self.b0
    a=self.f(z)
    y=tf.matmul(self.W1,a)+self.b1
    return y

# %% [markdown]
# Run the cell below several times. Each time the function shape changes.

# %%
import numpy as np
x=np.linspace(0,10,100)
f=Function(10,activation=rbf)
y=f(x)
plt.plot(x,y.numpy()[0])

# %% [markdown]
# ## How to fit the model to a given function?
#
# We need
# 1.   A measure to evaluate model fitness
# 2.   A loss function to find the optimal model
# 3.   Loss function may be identical to measure (but does not have to)
# 4. An optimization procedure that minimizes the loss

# %% [markdown]
# **TODO 1.2.1** Analyze the code in the cell below and complete the code of MSE function. MSE means Mean Squared Error

# %%
a = tf.Variable([1.0,2.0,3.0,4.5])
b = tf.Variable([1.0,2.1,3.8,4.0])
e = (a-b)**2

print(e)
mse=tf.reduce_mean(e)
print(mse)
# Out:
# tf.Tensor([0.         0.00999998 0.6399999  0.25      ], shape=(4,), dtype=float32)
# tf.Tensor(0.22499998, shape=(), dtype=float32)

# %%
def tf_MSE(y_true,y_pred):
  e = (y_true - y_pred)**2
  return tf.math.reduce_sum(e)/e.shape[0]

# %% [markdown]
# **TODO 1.2.2** Rewrite sigmoid and rbf functions using  TensorFlow

# %%
def tf_sigmoid(x):
  return tf.sigmoid(x)

def tf_rbf(x):
  return tf.exp(-1*tf.square(x))

# %% [markdown]
# ## The fit method
#
# * Input: x and y
# * Iterates multiple times (parameter epoch)
# * In each iteration
#   * Calculates y_pred = model(x)
#   * Computes loss function
#   * Computes gradient of loss function with respect to weights
#   * Updates weights, basicaly according to the formula $W=W-gradient*learning\_rate$.
#   * Actually uses an optimizer that performs this in a smarter way

# %%
import tensorflow as tf


class Function:
  def __init__(self,n_h,activation = lambda x:x):
    self.f = activation
    self.W0=tf.Variable(np.random.randn(n_h,1)*0.01)
    self.b0=tf.Variable(np.zeros((n_h,1)))
    self.W1=tf.Variable(np.random.randn(1,n_h)*0.01)
    self.b1=tf.Variable(np.zeros((1,1)))


  def __call__(self,x):
    z=self.W0*x+self.b0
    a=self.f(z)
    y=tf.matmul(self.W1,a)+self.b1
    return y


  def fit(self,x,y,epochs=10,optimizer = tf.keras.optimizers.RMSprop()):
    for i in range(epochs):
      with tf.GradientTape() as tape:
        y_pred=self(x)
        loss = tf_MSE(y_pred,y)
        # print(loss)
        variables=(self.W0,self.b0,self.W1,self.b1)
        gradients = tape.gradient(loss, variables)
        # print(gradients)
        optimizer.apply_gradients(zip(gradients, variables))

# %% [markdown]
# We will try to fit our model (Function class) to the polynomial  $y=(x-1)(x-6)(x-7)$

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,10,100)
y = (x-1)*(x-6)*(x-7)

plt.scatter(x,y)
plt.grid()

# %% [markdown]
# Although the problem is super-easy for methods numerical analysis, using this approach is a little bit hard. We need many hidden units and iterations... (execution abot 90 sec)
#
# **TODO 1.2.3** Create a model (Function) object passing as parameters 50 hidden units and rbf activation function. Fit the model setting number of iterations to 5000.

# %%
f=Function(50, activation=tf_rbf)
f.fit(x, y, epochs=5000)

plt.plot(x,y)
plt.grid()

y_pred=f(x)
plt.plot(x,y_pred.numpy()[0])

# %% [markdown]
# **Hyperparameters**
# *  n_h (number of hidden neurons) controls the model complexity
# *  activation function - influences the model performance
# *  epochs - controls number of iterations (influences the learning algorithm)

# %% [markdown]
# # 1.3 Implementation based on Pytorch

# %% [markdown]
# **TODO 1.3.1** Write functions  `torch_rbf` and `torch_MSE`

# %%
import torch

def torch_rbf(x):
    ...

x = torch.tensor([1.0, 2.0])

print(torch_rbf(x))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 import torch
#       3 def torch_rbf(x):
#       4     ...
#
# File ~\PycharmProjects\compuational_intelligence\huj\Lib\site-packages\torch\__init__.py:281
#     277                     raise err
#     279         kernel32.SetErrorMode(prev_error_mode)
# --> 281     _load_dll_libraries()
#     282     del _load_dll_libraries
#     285 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     286     # Libraries can either be in
#     287     # path/nvidia/lib_folder/lib or
#     288     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     289     # path/lib_folder/lib
#
# File ~\PycharmProjects\compuational_intelligence\huj\Lib\site-packages\torch\__init__.py:264, in _load_dll_libraries()
#     260     err = ctypes.WinError(last_error)
#     261     err.strerror += (
#     262         f' Error loading "{dll}" or one of its dependencies.'
#     263     )
# --> 264     raise err
#     265 elif res is not None:
#     266     is_loaded = True
#
# OSError: [WinError 193] %1 is not a valid Win32 application. Error loading "C:\Users\ogsimp\PycharmProjects\compuational_intelligence\huj\Lib\site-packages\torch\lib\shm.dll" or one of its dependencies.

# %%
def torch_MSE(y_pred, y_true):
    ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim




class Function(nn.Module):
    def __init__(self, n_h, activation=lambda x: x):
        super(Function, self).__init__()
        self.f = activation

        # nn.Parameter (analog of tf.Variable)
        self.W0 = nn.Parameter(torch.randn(n_h, 1) * 0.1)
        self.b0 = nn.Parameter(torch.zeros(n_h, 1))
        self.W1 = nn.Parameter(torch.randn(1, n_h) * 0.1)
        self.b1 = nn.Parameter(torch.zeros(1, 1))

    def forward(self, x):
        z = self.W0 @ x + self.b0   # computes: W0 * x + b0
        a = self.f(z)               # activation
        y = self.W1 @ a + self.b1   # computes: W1 * a + b1
        return y


    def fit(self, x, y, epochs=10, optimizer=None):
        if optimizer is None:
            optimizer = optim.RMSprop(self.parameters())

        for i in range(epochs):
            optimizer.zero_grad()         # sets gradients to 0
            y_pred = self.forward(x)
            loss = torch_MSE(y_pred, y)
            loss.backward()               # gradient computation
            optimizer.step()              # applying gradients to weights
            # print(loss.item())

# %%
model = Function(n_h=50, activation=torch_rbf)

x = np.linspace(0,10,100)
y = (x-1)*(x-6)*(x-7)

x_t = torch.tensor(x, dtype=torch.float32).unsqueeze(0)
y_t = torch.tensor(y, dtype=torch.float32).unsqueeze(0)
model.fit(x_t, y_t, epochs=5000)

y_pred = model(x_t)
print(y_pred)

# %%
plt.plot(x,y)
plt.grid()

plt.plot(x,y_pred.detach().numpy()[0])

# %% [markdown]
# # 1.4 TensorFlow: neural network model
#
# Analogous model can be built using components of tensorflow.keras library.
#
# *  **Advantage** the computations are converted to form a *computational graph* that can be executed much faster. Also on GPU. This is done with ```compile``` method.

# %%
from keras import models
from keras import layers

def build_model(n_h):
  model = models.Sequential()
  model.add(layers.Input(shape=(1,)))
  model.add(layers.Dense(n_h, activation=tf_rbf))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mse','mae'])
  return model

# %% [markdown]
# **TODO 1.4.1** Create a model with 50 hidden units and call fit function setting number of epochs 5000 and batch_size (another hyperparameter) to 100

# %%
import numpy as np
x = np.linspace(0,10,100)
y = (x-1)*(x-6)*(x-7)

model = ...
model.summary()
history = ...
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 50)             │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 151 (604.00 B)
#  Trainable params: 151 (604.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Check plots of original and fit curves

# %%
plt.figure(figsize=(15,10))

plt.plot(x,y)
plt.grid()

y_pred=model.predict(x)
plt.plot(x,y_pred)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# **TODO 1.4.2** Repat the above steps changing hyperparameters to get a good fit

# %% [markdown]
# During training some data are collected. We may display various measures residing in the training history

# %%
import matplotlib.pyplot as plt

plt.title('Training history - MSE')
plt.plot(history.history['mse'],label='mse')
plt.xlabel('iteration')
plt.ylabel('MSE')
plt.legend()

# history.history['mse']

# %% [markdown]
# # 1.5 PyTorch: Neural network model

# %% [markdown]
# In PyTorch activation function is a separate layer
#
#
# Information on loss should be explicitely collected
#
# ```
# history = {'loss': []}
#
# for epoch in range(epochs):
#     ...
#     history['loss'].append(loss.item())
#
# ```

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# --- RBF Layer ---
class RBF(nn.Module):
    def forward(self, x):
        return torch.exp(-x**2)

# %%
class SimpleRBFNN(nn.Module):
    def __init__(self, n_h):
        super().__init__()
        self.hidden = nn.Linear(1, n_h)
        self.rbf = RBF()
        self.out = nn.Linear(n_h, 1)

    def forward(self, x):
        x = self.hidden(x)
        x = self.rbf(x)
        x = self.out(x)
        return x

# %%
# datatype and shape conversion
x = np.linspace(0, 10, 100).reshape(-1, 1).astype(np.float32)
y = ((x - 1)*(x - 6)*(x - 7)).astype(np.float32)

x_tensor = torch.from_numpy(x)
y_tensor = torch.from_numpy(y)

# --- Model, optimizer, loss ---
model = SimpleRBFNN(n_h=50)
optimizer = optim.RMSprop(model.parameters())
loss_fn = nn.MSELoss()

# --- Trening ---
epochs = 5000
history = {'loss': []}

for epoch in range(epochs):
    optimizer.zero_grad()
    y_pred = model(x_tensor)
    loss = loss_fn(y_pred, y_tensor)
    loss.backward()
    optimizer.step()

    history['loss'].append(loss.item())

    if (epoch+1) % 1000 == 0:
        print(f"Epoch {epoch+1}, Loss: {loss.item():.6f}")

# --- Sprawdzenie wyników ---
with torch.no_grad():
    y_pred = model(x_tensor)
# Out:
# Epoch 1000, Loss: 23.392874
# Epoch 2000, Loss: 5.421781
# Epoch 3000, Loss: 5.261586
# Epoch 4000, Loss: 5.169375
# Epoch 5000, Loss: 5.007264

# %% [markdown]
# **prior to conversion to numpy, gradients should be detached ...**

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))

plt.plot(x,y)
plt.grid()

y_pred=model(x_tensor).detach().numpy()
plt.plot(x,y_pred)

# %%
plt.plot(history['loss'])

# %% [markdown]
# # 1.6 More realistic problem
# The task of perfectly fitting a known function is very rare.
#
# *  It is rather assumed that we have data that originate from a true underlaying function with a noise $y=f(x)+\varepsilon$
# *  It is also often assumed that $\varepsilon \sim N(0,\sigma)$

# %%
from keras import models
from keras import layers
import numpy as np
import matplotlib.pyplot as plt

n_size=100
x = np.linspace(0,10,n_size)
y = (x-1)*(x-6)*(x-7)+np.random.normal(0,10,n_size)

plt.scatter(x,y)
plt.plot(x,(x-1)*(x-6)*(x-7),color='g')

# %% [markdown]
# ## 1.6.1 Tensorflow

# %% [markdown]
# **TODO 1.6.1** Fit the model to this DATA using the best hyperparameters obtained before

# %%
model = ...
history = ...

# %% [markdown]
# **TODO 1.6.2** Plot the scattered data, true function in green and predictions in red

# %%
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %% [markdown]
# ## 1.6.2 Pytorch

# %% [markdown]
# **TODO 1.6.3** Write analogous code using PyTorch library. Select number of epochs providing the best results (no underfitting / overfitting. Plot the results.
#
# Collect information on loss and display it.

# %%
# Example 1

# %%
# Example 2

# %%
# Example 3

# %% [markdown]
# # 1.7 Validating model - training and testing
#
# Typical ML workflow includes training the model and testing its performance on unseen data.
#
# * **Why** - to control and assess generalization error which may result from
#     * underfitting - the model is to simple or not trained enough
#     * overfitting - the model is too complex, matches perfectly the training data (see part of the plot on the left)

# %% [markdown]
# We will split the data into two subsets

# %%
from sklearn.model_selection import train_test_split

x = np.linspace(0,10,n_size)
y = (x-1)*(x-6)*(x-7)+np.random.normal(0,10,n_size)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=123)

# %% [markdown]
# ## 1.7.1 TensorFlow

# %% [markdown]
# **TODO 1.7.1** Fit the TensorFlow model using x_train and y_train, set the parameter ```validation_data=(x_test, y_test)```
#
# Warning: training lasts up to 250 sec

# %% [markdown]
# We will display true function, noisy data and predictions

# %%
plt.scatter(x_test,y_test)
plt.plot(x,(x-1)*(x-6)*(x-7),color='g')
y_pred=model.predict(x_test)
plt.scatter(x_test,y_pred,color='r')
# plt.plot(x_test,y_pred,color='r')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %% [markdown]
# Lets peek what is the content of the history...

# %%
for k in history.history:
  print(k)
# Out:
# loss
# mae
# mse
# val_loss
# val_mae
# val_mse

# %% [markdown]
# **TODO 1.7.2** Display loss (training loss) and val_loss (validation loss on the test set)

# %% [markdown]
# ## 1.7.2 PyTorch
# **TODO 1.7.3** Perform analogous task using PyTorch.
#
# While evaluating model on test data you should not compute gradients. The typical code snippet is:
#
# ```
#     # Within the traing loop
#     model.eval()
#     with torch.no_grad():
#         y_val_pred = model(X_test)
#         val_loss = loss_fn(y_val_pred, y_test)
#
# ```
# See also: https://stackoverflow.com/questions/60018578/what-does-model-eval-do-in-pytorch

# %%
x_train = x_train.reshape(-1, 1).astype(np.float32)
y_train = y_train.reshape(-1, 1).astype(np.float32)

x_test = x_test.reshape(-1, 1).astype(np.float32)
y_test = y_test.reshape(-1, 1).astype(np.float32)

x_tensor_train = torch.from_numpy(x_train)
y_tensor_train = torch.from_numpy(y_train)

x_tensor_test = torch.from_numpy(x_test)
y_tensor_test = torch.from_numpy(y_test)

# --- Model, optimizer, loss ---
model = SimpleRBFNN(n_h=50)
optimizer = optim.RMSprop(model.parameters())
loss_fn = nn.MSELoss()

# --- Traning ---

# %%
plt.scatter(x_test,y_test)
plt.plot(x,(x-1)*(x-6)*(x-7),color='g')
y_pred=model(x_tensor_test)
plt.scatter(x_test,y_pred.detach().numpy(),color='r')
# plt.plot(x_test,y_pred,color='r')

# %%
plt.plot(history['loss'],label='train loss')
plt.plot(history['val_loss'],label='validation loss')
plt.legend()

# %% [markdown]
# # 1.8 Classification
# Function models can be used for classification, provided we constrain them to return probabilities, i.e.  values from [0,1] interval.
#
# * Function with one output may be used for binary classification:
#   *  Assign $label_0$ if $f(x) <0.5$
#   *  Assign $label_1$ if $f(x) \ge 0.5$
#
# **TODO 1.8.1** Which function converts $R \to [0,1]$? Answer the question

# %%
import matplotlib.pyplot as plt
x=np.linspace(-10,10,100)

plt.plot(x,(lambda x: 1/(1+np.exp(-x)))(x),c='r')

# %% [markdown]
# We will generate a dataset. Points above the previously used polynomial will have blue label, the points below red.

# %%
X = np.random.rand(1000,2)*[10,150]-[0,40]
y = np.where(X[:,1]>(X[:,0]-1)*(X[:,0]-6)*(X[:,0]-7),1,0)
# y.shape

from matplotlib.colors import ListedColormap
cm = ListedColormap(['r', 'b'])
plt.scatter(X[:,0],X[:,1],c=y,cmap=cm)

# %% [markdown]
# We will biuld a model more suitable for classification.
#
# What is binary_crossentropy aka. logloss?
#
# $loss_i= -[ y_i\cdot ln(p_i) + (1-y_i)\cdot ln(1-p_i)]$
#
# You may google the term...
#
# $p_i=f(x_1)$
#
# $y_i = 1 → p_i = 1 (.9)$
#
# $y_i = 0 → p_i = 0 (.1)$

# %% [markdown]
# ## 1.8.1 Classification in TensorFlow

# %%
import tensorflow as tf


def build_classification_model(n_h):
  model = models.Sequential()
  model.add(layers.Input(shape=(2,)))
  model.add(layers.Dense(n_h, activation='relu'))
  model.add(layers.Dense(n_h, activation='relu'))
  model.add(layers.Dense(1,activation='sigmoid'))
  model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# **TODO 1.8.2** fit the model using training data. Set about 100 epochs, use X_test and y_test as validation data.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.3665 - loss: 4.5110 - val_accuracy: 0.4033 - val_loss: 3.8516
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3624 - loss: 3.7022 - val_accuracy: 0.4033 - val_loss: 3.0795
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3441 - loss: 3.0487 - val_accuracy: 0.4033 - val_loss: 2.3546
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3875 - loss: 2.0960 - val_accuracy: 0.3967 - val_loss: 1.7010
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3546 - loss: 1.5152 - val_accuracy: 0.3933 - val_loss: 1.1208
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3564 - loss: 1.0409 - val_accuracy: 0.4033 - val_loss: 0.6759
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4501 - loss: 0.6245 - val_accuracy: 0.8967 - val_loss: 0.4252
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8883 - loss: 0.4264 - val_accuracy: 0.8967 - val_loss: 0.3199
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8904 - loss: 0.3402 - val_accuracy: 0.8967 - val_loss: 0.2787
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8652 - loss: 0.3341 - val_accuracy: 0.8967 - val_loss: 0.2611
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9208 - loss: 0.2550 - val_accuracy: 0.8967 - val_loss: 0.2515
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8853 - loss: 0.2883 - val_accuracy: 0.9000 - val_loss: 0.2460
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8820 - loss: 0.2889 - val_accuracy: 0.9000 - val_loss: 0.2427
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8930 - loss: 0.2703 - val_accuracy: 0.9033 - val_loss: 0.2398
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8961 - loss: 0.2799 - val_accuracy: 0.9033 - val_loss: 0.2381
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9049 - loss: 0.2583 - val_accuracy: 0.9067 - val_loss: 0.2370
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8982 - loss: 0.2710 - val_accuracy: 0.9067 - val_loss: 0.2357
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8992 - loss: 0.2700 - val_accuracy: 0.9067 - val_loss: 0.2345
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8906 - loss: 0.2873 - val_accuracy: 0.9033 - val_loss: 0.2336
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8953 - loss: 0.2587 - val_accuracy: 0.9100 - val_loss: 0.2324
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9073 - loss: 0.2480 - val_accuracy: 0.9100 - val_loss: 0.2317
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8783 - loss: 0.3015 - val_accuracy: 0.9100 - val_loss: 0.2315
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9059 - loss: 0.2505 - val_accuracy: 0.9133 - val_loss: 0.2303
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9012 - loss: 0.2677 - val_accuracy: 0.9133 - val_loss: 0.2299
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8956 - loss: 0.2813 - val_accuracy: 0.9133 - val_loss: 0.2298
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9041 - loss: 0.2636 - val_accuracy: 0.9133 - val_loss: 0.2291
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8986 - loss: 0.2663 - val_accuracy: 0.9133 - val_loss: 0.2287
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8938 - loss: 0.2802 - val_accuracy: 0.9133 - val_loss: 0.2284
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9017 - loss: 0.2593 - val_accuracy: 0.9133 - val_loss: 0.2278
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8877 - loss: 0.2970 - val_accuracy: 0.9133 - val_loss: 0.2276
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8865 - loss: 0.2865 - val_accuracy: 0.9133 - val_loss: 0.2271
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9010 - loss: 0.2681 - val_accuracy: 0.9133 - val_loss: 0.2267
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8915 - loss: 0.2673 - val_accuracy: 0.9133 - val_loss: 0.2265
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8995 - loss: 0.2486 - val_accuracy: 0.9133 - val_loss: 0.2266
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8918 - loss: 0.2969 - val_accuracy: 0.9133 - val_loss: 0.2269
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9074 - loss: 0.2579 - val_accuracy: 0.9133 - val_loss: 0.2263
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9018 - loss: 0.2537 - val_accuracy: 0.9133 - val_loss: 0.2257
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9123 - loss: 0.2370 - val_accuracy: 0.9133 - val_loss: 0.2255
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8901 - loss: 0.2948 - val_accuracy: 0.9133 - val_loss: 0.2259
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9003 - loss: 0.2548 - val_accuracy: 0.9133 - val_loss: 0.2254
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9052 - loss: 0.2572 - val_accuracy: 0.9133 - val_loss: 0.2253
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8927 - loss: 0.2845 - val_accuracy: 0.9133 - val_loss: 0.2256
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8930 - loss: 0.2768 - val_accuracy: 0.9133 - val_loss: 0.2255
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9056 - loss: 0.2578 - val_accuracy: 0.9133 - val_loss: 0.2251
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9088 - loss: 0.2462 - val_accuracy: 0.9133 - val_loss: 0.2247
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8902 - loss: 0.2851 - val_accuracy: 0.9133 - val_loss: 0.2251
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8966 - loss: 0.2671 - val_accuracy: 0.9133 - val_loss: 0.2248
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8967 - loss: 0.2752 - val_accuracy: 0.9133 - val_loss: 0.2247
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9120 - loss: 0.2396 - val_accuracy: 0.9133 - val_loss: 0.2241
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8842 - loss: 0.2912 - val_accuracy: 0.9133 - val_loss: 0.2243
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9109 - loss: 0.2530 - val_accuracy: 0.9133 - val_loss: 0.2243
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8929 - loss: 0.2837 - val_accuracy: 0.9133 - val_loss: 0.2242
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8888 - loss: 0.2790 - val_accuracy: 0.9133 - val_loss: 0.2239
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9016 - loss: 0.2526 - val_accuracy: 0.9133 - val_loss: 0.2236
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8997 - loss: 0.2500 - val_accuracy: 0.9133 - val_loss: 0.2235
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8907 - loss: 0.2775 - val_accuracy: 0.9133 - val_loss: 0.2234
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8908 - loss: 0.2926 - val_accuracy: 0.9133 - val_loss: 0.2235
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8895 - loss: 0.2682 - val_accuracy: 0.9133 - val_loss: 0.2234
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8979 - loss: 0.2610 - val_accuracy: 0.9133 - val_loss: 0.2233
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9052 - loss: 0.2664 - val_accuracy: 0.9133 - val_loss: 0.2232
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9139 - loss: 0.2540 - val_accuracy: 0.9133 - val_loss: 0.2229
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8925 - loss: 0.2731 - val_accuracy: 0.9133 - val_loss: 0.2233
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8986 - loss: 0.2672 - val_accuracy: 0.9133 - val_loss: 0.2229
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8978 - loss: 0.2649 - val_accuracy: 0.9133 - val_loss: 0.2223
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9034 - loss: 0.2498 - val_accuracy: 0.9133 - val_loss: 0.2222
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9171 - loss: 0.2375 - val_accuracy: 0.9133 - val_loss: 0.2223
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9004 - loss: 0.2630 - val_accuracy: 0.9133 - val_loss: 0.2225
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9114 - loss: 0.2311 - val_accuracy: 0.9133 - val_loss: 0.2223
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8952 - loss: 0.2607 - val_accuracy: 0.9133 - val_loss: 0.2224
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9059 - loss: 0.2485 - val_accuracy: 0.9133 - val_loss: 0.2222
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9063 - loss: 0.2493 - val_accuracy: 0.9133 - val_loss: 0.2221
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9005 - loss: 0.2586 - val_accuracy: 0.9133 - val_loss: 0.2223
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8992 - loss: 0.2663 - val_accuracy: 0.9133 - val_loss: 0.2223
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8911 - loss: 0.2714 - val_accuracy: 0.9133 - val_loss: 0.2222
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8949 - loss: 0.2595 - val_accuracy: 0.9133 - val_loss: 0.2224
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8976 - loss: 0.2685 - val_accuracy: 0.9133 - val_loss: 0.2224
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8959 - loss: 0.2550 - val_accuracy: 0.9133 - val_loss: 0.2220
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8858 - loss: 0.2747 - val_accuracy: 0.9133 - val_loss: 0.2221
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8948 - loss: 0.2667 - val_accuracy: 0.9133 - val_loss: 0.2224
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8967 - loss: 0.2624 - val_accuracy: 0.9133 - val_loss: 0.2221
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9015 - loss: 0.2537 - val_accuracy: 0.9133 - val_loss: 0.2220
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8872 - loss: 0.2812 - val_accuracy: 0.9133 - val_loss: 0.2219
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9150 - loss: 0.2375 - val_accuracy: 0.9133 - val_loss: 0.2213
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9119 - loss: 0.2451 - val_accuracy: 0.9133 - val_loss: 0.2213
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9043 - loss: 0.2549 - val_accuracy: 0.9133 - val_loss: 0.2211
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8888 - loss: 0.2759 - val_accuracy: 0.9133 - val_loss: 0.2208
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9008 - loss: 0.2578 - val_accuracy: 0.9133 - val_loss: 0.2207
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9078 - loss: 0.2508 - val_accuracy: 0.9133 - val_loss: 0.2208
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8953 - loss: 0.2631 - val_accuracy: 0.9133 - val_loss: 0.2209
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9054 - loss: 0.2698 - val_accuracy: 0.9133 - val_loss: 0.2202
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9002 - loss: 0.2607 - val_accuracy: 0.9133 - val_loss: 0.2197
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8972 - loss: 0.2618 - val_accuracy: 0.9133 - val_loss: 0.2190
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9046 - loss: 0.2641 - val_accuracy: 0.9133 - val_loss: 0.2196
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8986 - loss: 0.2571 - val_accuracy: 0.9133 - val_loss: 0.2179
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9045 - loss: 0.2576 - val_accuracy: 0.9133 - val_loss: 0.2181
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9116 - loss: 0.2481 - val_accuracy: 0.9133 - val_loss: 0.2183
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9106 - loss: 0.2506 - val_accuracy: 0.9133 - val_loss: 0.2194
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8981 - loss: 0.2587 - val_accuracy: 0.9133 - val_loss: 0.2184
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9110 - loss: 0.2271 - val_accuracy: 0.9133 - val_loss: 0.2187
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8926 - loss: 0.2579 - val_accuracy: 0.9133 - val_loss: 0.2186

# %% [markdown]
# Display predictions and the polynomial curve which was used to separate class instances.

# %%
y_pred = model.predict(X_test)
plt.scatter(X_test[:,0],X_test[:,1],c=y_pred,cmap=cm)
x = np.linspace(0,10,100)
y = (x-1)*(x-6)*(x-7)
plt.plot(x,y,color='g')
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
plt.plot(history.history['loss'],label='train loss')
plt.plot(history.history['val_loss'],label='validation loss')
plt.legend()

# %% [markdown]
# ## 1.8.1 Classification in Pytorch

# %% [markdown]
# **TODO 1.8.3** Build PyTorch model with the same architecture as TensorFlow. Split X,y dataset to train and test data. Train the model and collect loss and validation loss in the history dictionary. Display plots.

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# --- Model ---
class ClassificationModel(nn.Module):
    def __init__(self, n_h):
        super().__init__()
        self.hidden1 = nn.Linear(2, n_h)     # Input (2) -> n_h
        self.hidden2 = nn.Linear(n_h, n_h)   # n_h -> n_h
        self.out = nn.Linear(n_h, 1)         # n_h -> 1
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.hidden1(x))   # 1. Dense + ReLU
        x = ...   # 2. Dense + ReLU
        x = ...    # Output + Sigmoid
        return x

# %%
X = np.random.rand(1000,2)*[10,150]-[0,40]
y = np.where(X[:,1]>(X[:,0]-1)*(X[:,0]-6)*(X[:,0]-7),1,0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
X_train = torch.from_numpy(X_train).float()
y_train = torch.from_numpy(y_train).float()
X_test = torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test).float()

# Reshape y_train and y_test to match the model output shape
y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

# --- Model, optimizer, loss ---
model = ClassificationModel(n_h=32)
optimizer = optim.Adam(model.parameters())
loss_fn = nn.BCELoss()

# %%
y_pred = model(X_test)
plt.scatter(X_test[:,0],X_test[:,1],c=y_pred.detach().numpy(),cmap=cm)
x = np.linspace(0,10,100)
y = (x-1)*(x-6)*(x-7)
plt.plot(x,y,color='g')

# %%
plt.plot(history['loss'],label='train loss')
plt.plot(history['val_loss'],label='validation loss')
plt.legend()
